# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm, tnrange
# %matplotlib inline

# %%
df = pd.read_excel("Train/train_Data.xlsx")
tdf = pd.read_excel("Test/test_Data.xlsx")
df.head()
# Out:
#    ID Frequency InstlmentMode LoanStatus   PaymentMode  BranchID      Area  \
# 0   1   Monthly        Arrear     Closed         PDC_E         1       NaN
# 1   2   Monthly       Advance     Closed           PDC       333    BHOPAL
# 2   3   Quatrly        Arrear     Active  Direct Debit         1       NaN
# 3   7   Monthly       Advance     Closed        Billed       125      GUNA
# 4   8   Monthly        Arrear     Closed        Billed       152  BILASPUR
#
#    Tenure  AssetCost  AmountFinance  ...  ManufacturerID  SupplierID    LTV  \
# 0      48     450000       275000.0  ...            1568       21946  61.11
# 1      47     485000       350000.0  ...            1062       34802  70.00
# 2      68     690000       519728.0  ...            1060      127335  69.77
# 3      48     480000       400000.0  ...            1060       25094  80.92
# 4      44     619265       440000.0  ...            1046       21853  71.05
#
#   SEX   AGE  MonthlyIncome         City           State   ZiPCODE  \
# 0   M  49.0       35833.33       RAISEN  MADHYA PRADESH  464993.0
# 1   M  23.0         666.67       SEHORE  MADHYA PRADESH  466001.0
# 2   M  39.0       45257.00       BHOPAL  MADHYA PRADESH  462030.0
# 3   M  24.0       20833.33  ASHOK NAGAR  MADHYA PRADESH  473335.0
# 4   M  56.0       27313.67     BILASPUR     CHATTISGARH  495442.0
#
#         Top-up Month
# 0        > 48 Months
# 1  No Top-up Service
# 2       12-18 Months
# 3        > 48 Months
# 4       36-48 Months
#
# [5 rows x 26 columns]

# %%
df.shape, df.ID.nunique(), tdf.shape, tdf.ID.nunique(),
# Out:
# ((128655, 26), 128655, (14745, 25), 14745)

# %% [markdown]
# # train demographic data

# %%
cat_cols = ['Frequency', 'InstlmentMode', 'LoanStatus', 'PaymentMode', 'BranchID', 'Area', 
            'ManufacturerID', 'SupplierID', 'SEX', 'City', 'State', 'ZiPCODE', 'Top-up Month']
reg_cols = ['AmountFinance', 'DisbursalAmount', 'EMI', 'AssetID', 'MonthlyIncome', 'Tenure', 'AssetCost', 'LTV', 'AGE']
date_cols = ['DisbursalDate', 'MaturityDAte', 'AuthDate']
len(cat_cols) + len(reg_cols) + len(date_cols)
# Out:
# 25

# %%
df.isnull().sum()
# Out:
# ID                     0
# Frequency              0
# InstlmentMode          0
# LoanStatus             0
# PaymentMode            0
# BranchID               0
# Area               11653
# Tenure                 0
# AssetCost              0
# AmountFinance          0
# DisbursalAmount        0
# EMI                    0
# DisbursalDate          0
# MaturityDAte           1
# AuthDate               0
# AssetID                0
# ManufacturerID         0
# SupplierID             0
# LTV                    0
# SEX                   59
# AGE                   59
# MonthlyIncome        234
# City               11256
# State                  0
# ZiPCODE              372
# Top-up Month           0
# dtype: int64

# %%
tdf.isnull().sum()
# Out:
# ID                   0
# Frequency            0
# InstlmentMode        0
# LoanStatus           0
# PaymentMode          0
# BranchID             0
# Area               546
# Tenure               0
# AssetCost            0
# AmountFinance        0
# DisbursalAmount      0
# EMI                  0
# DisbursalDate        0
# MaturityDAte         0
# AuthDate             0
# AssetID              0
# ManufacturerID       2
# SupplierID           0
# LTV                  0
# SEX                  5
# AGE                  7
# MonthlyIncome       14
# City                 0
# State                0
# ZiPCODE              1
# dtype: int64

# %%
for col in cat_cols:
    if col in df.columns:
        print("col {} : unique {}".format(col, df[col].nunique()))
    
    if col in tdf.columns:
        print("col {} : unique {}".format(col, tdf[col].nunique()))
    print("----------")
# Out:
# col Frequency : unique 4
# col Frequency : unique 3
# ----------
# col InstlmentMode : unique 2
# col InstlmentMode : unique 2
# ----------
# col LoanStatus : unique 2
# col LoanStatus : unique 2
# ----------
# col PaymentMode : unique 11
# col PaymentMode : unique 10
# ----------
# col BranchID : unique 189
# col BranchID : unique 182
# ----------
# col Area : unique 92
# col Area : unique 80
# ----------
# col ManufacturerID : unique 10
# col ManufacturerID : unique 12
# ----------
# col SupplierID : unique 4539
# col SupplierID : unique 1573
# ----------
# col SEX : unique 2
# col SEX : unique 2
# ----------
# col City : unique 488
# col City : unique 321
# ----------
# col State : unique 22
# col State : unique 18
# ----------
# col ZiPCODE : unique 9123
# col ZiPCODE : unique 2182
# ----------
# col Top-up Month : unique 7
# ----------

# %%
for col in reg_cols:
    if col in df.columns:
        print("col {} : unique {}".format(col, df[col].nunique()))
    
    if col in tdf.columns:
        print("col {} : unique {}".format(col, tdf[col].nunique()))
    print("----------")
# Out:
# col AmountFinance : unique 20439
# col AmountFinance : unique 4066
# ----------
# col DisbursalAmount : unique 19412
# col DisbursalAmount : unique 3978
# ----------
# col EMI : unique 24323
# col EMI : unique 4370
# ----------
# col AssetID : unique 128655
# col AssetID : unique 14745
# ----------
# col MonthlyIncome : unique 11568
# col MonthlyIncome : unique 2470
# ----------
# col Tenure : unique 141
# col Tenure : unique 98
# ----------
# col AssetCost : unique 7835
# col AssetCost : unique 1162
# ----------
# col LTV : unique 7988
# col LTV : unique 5101
# ----------
# col AGE : unique 73
# col AGE : unique 65
# ----------

# %%
for col in cat_cols:
    if col in df.columns:
        fig, ax = plt.subplots()
        df[col].value_counts().plot(ax=ax, kind='bar', title=col)

# %%
df.isnull().sum()
# Out:
# ID                     0
# Frequency              0
# InstlmentMode          0
# LoanStatus             0
# PaymentMode            0
# BranchID               0
# Area               11653
# Tenure                 0
# AssetCost              0
# AmountFinance          0
# DisbursalAmount        0
# EMI                    0
# DisbursalDate          0
# MaturityDAte           1
# AuthDate               0
# AssetID                0
# ManufacturerID         0
# SupplierID             0
# LTV                    0
# SEX                   59
# AGE                   59
# MonthlyIncome        234
# City               11256
# State                  0
# ZiPCODE              372
# Top-up Month           0
# dtype: int64

# %% [markdown]
# # fix missing city

# %%
# check if all values are either nan or whole numbers
    
x_int1 = df.ZiPCODE[~df.ZiPCODE.isnull()].values.astype(int)
x_int2 = tdf.ZiPCODE[~tdf.ZiPCODE.isnull()].values.astype(int)

np.all((df.ZiPCODE[~df.ZiPCODE.isnull()] - x_int1) == 0), np.all((tdf.ZiPCODE[~tdf.ZiPCODE.isnull()] - x_int2) == 0)
# Out:
# (True, True)

# %%
# check if a zip code can be mapped to different area

both_area_pin_missing = 0
both_city_pin_missing = 0
both_area_city_missing = 0
all_three_missing = 0

for area, pin, city in zip(df.Area.values, df.ZiPCODE.values, df.City.values):
    # there is no place where both pin and area are missing
    x = np.isnan(pin)
    y = pd.isnull(area)
    z = pd.isnull(city)
    if x and y: both_area_pin_missing += 1
    if y and z: both_area_city_missing += 1
    if x and z: both_city_pin_missing += 1
    if x and y and z: all_three_missing += 1
both_area_pin_missing, both_area_city_missing, both_city_pin_missing, all_three_missing
# Out:
# (48, 1505, 344, 47)

# %%
# check if a zip code can be mapped to different area

both_area_pin_missing = 0
both_city_pin_missing = 0
both_area_city_missing = 0
all_three_missing = 0

for area, pin, city in zip(tdf.Area.values, tdf.ZiPCODE.values, tdf.City.values):
    # there is no place where both pin and area are missing
    x = np.isnan(pin)
    y = pd.isnull(area)
    z = pd.isnull(city)
    if x and y: both_area_pin_missing += 1
    if y and z: both_area_city_missing += 1
    if x and z: both_city_pin_missing += 1
    if x and y and z: all_three_missing += 1
both_area_pin_missing, both_area_city_missing, both_city_pin_missing, all_three_missing
# Out:
# (0, 0, 0, 0)

# %%
# can a pin be mapped to several cities
pin_city_mapping = {}
for city, pin in zip(df.City.values, df.ZiPCODE.values):
    if not (np.isnan(pin) or pd.isnull(city)):
        if pin in pin_city_mapping:
            pin_city_mapping[pin].add(city)
        else:
            pin_city_mapping[pin] = set([city])
for pin in pin_city_mapping:
    x = pin_city_mapping[pin]
    if len(x) > 1:
        print("{}: {}".format(pin, x))
# Out:
# 713101.0: {'BURDWAN', 'BIRBHUM'}
# 722138.0: {'KOLKATA', 'BANKURA'}
# 741137.0: {'KOLKATA', 'NADIA'}
# 145001.0: {'PATHANKOT', 'JALANDHAR (PATHANKOT)'}
# 145025.0: {'PATHANKOT', 'GURDASPUR'}
# 584123.0: {'RAICHUR', 'MANVI'}
# 142043.0: {'FIROZPUR', 'MOGA'}
# 141801.0: {'LUDHIANA', 'FATEHGARH SAHIB'}
# 733140.0: {'KOLKATA', 'DAKSHIN DINAJPUR'}
# 160055.0: {'MOHALI', 'RUPNAGAR'}
# 125113.0: {'FATEHABAD', 'HISAR'}
# 125052.0: {'FATEHABAD', 'HISAR'}
# 741155.0: {'KOLKATA', 'NADIA'}
# 742101.0: {'MURSHIDABAD', 'BAHARAMPUR'}
# 134202.0: {'PANCHKULA', 'AMBALA'}
# 140101.0: {'RUPNAGAR', 'FATEHGARH SAHIB'}
# 210421.0: {'HAMIRPUR', 'MAHOBA'}
# 229303.0: {'PRATAPGARH', 'RAI BARELI'}
# 229010.0: {'BARELI', 'RAI BARELI'}
# 577413.0: {'SHIMOGA', '506'}
# 577243.0: {'DAVANGARE', 'SHIMOGA'}
# 505532.0: {'6', 'KARIMNAGAR'}
# 224122.0: {'AKBARPUR NEAR KANPUR', 'AMBEDKAR NAGAR'}
# 389235.0: {'VADODARA', 'PANCH MAHALS'}
# 431522.0: {'LATUR', 'OSMANABAD'}
# 441207.0: {'GADCHIROLI', 'CHANDRAPUR'}
# 442302.0: {'AMRAVATI', 'WARDHA'}
# 414603.0: {'AHMED NAGAR', 'Newasa'}
# 425413.0: {'DHULE', 'NANDURBAR'}
# 360490.0: {'RAJKOT', 'PORBANDAR'}
# 360590.0: {'JAMNAGAR', 'PORBANDAR'}
# 507134.0: {'EAST GODAVARI', 'KHAMMAM'}
# 152028.0: {'FIROZPUR', 'MOGA'}
# 147104.0: {'FATEHGARH SAHIB', 'PATIALA'}
# 140112.0: {'RUPNAGAR', 'FATEHGARH SAHIB'}
# 123027.0: {'MAHENDRAGARH', 'REWARI'}
# 123401.0: {'GURGAON', 'REWARI'}
# 450001.0: {'BURHANPUR', 'KHANDWA'}
# 450661.0: {'BURHANPUR', 'KHANDWA'}
# 458553.0: {'MANDSAUR', 'NEEMUCH'}
# 486445.0: {'REWA', 'SATNA'}
# 125048.0: {'FATEHABAD', 'HISAR'}
# 585214.0: {'GULBARGA', 'YADGIR'}
# 206301.0: {'ETAWAH', 'MAINPURI'}
# 824207.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824118.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824125.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824112.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824208.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824202.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824123.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824124.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824121.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824102.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824122.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824101.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824111.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824301.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824103.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 844506.0: {'VAISHALI', 'SAMASTIPUR'}
# 824120.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 844111.0: {'1947', 'VAISHALI'}
# 824113.0: {'AURANGABAD', 'AURANGABAD(BH)'}
# 824203.0: {'AURANGABAD', 'AURANGABAD(BH)'}

# %%
df[df.City == 'JALANDHAR (PATHANKOT)'].shape, df[df.City == 'JALANDHAR'].shape,  df[df.City == 'PATHANKOT'].shape
# Out:
# ((37, 26), (316, 26), (4, 26))

# %%
city_mappings = {
    "AURANGABAD(BH)": "AURANGABAD",
    '6': 'KARIMNAGAR',
    '506': 'SHIMOGA',
    '1947': 'VAISHALI'
}
pin_city_mappings = {}

# %%
# check how many cities have numbers in them
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)
for city, pin in zip(df.City.values, df.ZiPCODE.values):
    if not pd.isnull(city):
        if hasNumbers(city):
            print(city, pin)
# Out:
# 506 577413.0
# 506 577413.0
# 506 577413.0
# 506 577413.0
# 506 577413.0
# 6 505532.0
# 6 505532.0
# 6 505532.0
# 6 505532.0
# 6 505532.0
# 6 505532.0
# 1947 844111.0
# 1947 844111.0
# 1947 844111.0
# 1947 844111.0
# 1947 844111.0
# 1947 844111.0
# 1947 844111.0
# 1947 844111.0

# %%
# fixing numbers and aurangabad
df['City'] = df['City'].apply(lambda x: city_mappings[x] if x in city_mappings else x)

# %%
# creating area => city, pin => area, pin => city
area_city = {}
pin_area = {}
pin_city = {}
city_area = {}
for area, pin, city in zip(df.Area.values, df.ZiPCODE.values, df.City.values):
    x = np.isnan(pin)
    y = pd.isnull(area)
    z = pd.isnull(city)
    
    if not (x or y): 
        if pin not in pin_area: pin_area[pin] = set()
        pin_area[pin].add(area)
    if not (x or z):
        if pin not in pin_city: pin_city[pin] = set()
        pin_city[pin].add(city)
    
    if not (y or z):
        if area not in area_city: area_city[area] = set()
        area_city[area].add(city)
        if city not in city_area: city_area[city] = set()
        city_area[city].add(area)
len(area_city), len(pin_area), len(pin_city), len(city_area)
# Out:
# (92, 8492, 8698, 466)

# %%
to_solve = 11256
solved = 0
for area, pin, city in zip(df.Area.values, df.ZiPCODE.values, df.City.values):
    if pd.isnull(city):
        # first check if it can be replaced by pin_city
        try:
            if not np.isnan(pin) and len(pin_city[pin]) == 1:
                solved += 1
        except:
            print("pin not found {}".format(pin))
solved
# Out:
# pin not found 753008.0
# pin not found 759145.0
# pin not found 753010.0
# pin not found 756010.0
# pin not found 713359.0
# pin not found 722102.0
# pin not found 713338.0
# pin not found 722102.0
# pin not found 713378.0
# pin not found 713384.0
# pin not found 713359.0
# pin not found 713201.0
# pin not found 731218.0
# pin not found 722102.0
# pin not found 713378.0
# pin not found 732213.0
# pin not found 741101.0
# pin not found 303106.0
# pin not found 305011.0
# pin not found 209701.0
# pin not found 263001.0
# pin not found 263139.0
# pin not found 263001.0
# pin not found 380025.0
# pin not found 382023.0
# pin not found 382481.0
# pin not found 382325.0
# pin not found 391113.0
# pin not found 440002.0
# pin not found 440004.0
# pin not found 411039.0
# pin not found 508002.0
# pin not found 141106.0
# pin not found 173204.0
# pin not found 132145.0
# pin not found 132145.0
# pin not found 134002.0
# pin not found 121001.0
# pin not found 147204.0
# pin not found 147204.0
# pin not found 147204.0
# pin not found 121001.0
# pin not found 461114.0
# pin not found 334501.0
# pin not found 462032.0
# pin not found 462033.0
# pin not found 462035.0
# pin not found 464846.0
# pin not found 464471.0
# pin not found 463120.0
# pin not found 466002.0
# pin not found 464465.0
# pin not found 466002.0
# pin not found 464447.0
# pin not found 464667.0
# pin not found 462024.0
# pin not found 464667.0
# pin not found 462007.0
# pin not found 466002.0
# pin not found 466337.0
# pin not found 464991.0
# pin not found 464667.0
# pin not found 462037.0
# pin not found 466002.0
# pin not found 464576.0
# pin not found 493211.0
# pin not found 491835.0
# pin not found 492413.0
# pin not found 490013.0
# pin not found 495015.0
# pin not found 473551.0
# pin not found 473118.0
# pin not found 461991.0
# pin not found 464264.0
# pin not found 464214.0
# pin not found 469228.0
# pin not found 764053.0
# pin not found 754287.0
# pin not found 761019.0
# pin not found 751025.0
# pin not found 753011.0
# pin not found 755024.0
# pin not found 752030.0
# pin not found 761209.0
# pin not found 764069.0
# pin not found 753011.0
# pin not found 759105.0
# pin not found 754239.0
# pin not found 761056.0
# pin not found 752018.0
# pin not found 751012.0
# pin not found 754073.0
# pin not found 754073.0
# pin not found 761101.0
# pin not found 752010.0
# pin not found 764069.0
# pin not found 761918.0
# pin not found 761101.0
# pin not found 761131.0
# pin not found 761054.0
# pin not found 754024.0
# pin not found 753002.0
# pin not found 764069.0
# pin not found 759122.0
# pin not found 764069.0
# pin not found 764069.0
# pin not found 761040.0
# pin not found 751006.0
# pin not found 750025.0
# pin not found 759122.0
# pin not found 751050.0
# pin not found 761143.0
# pin not found 761019.0
# pin not found 754118.0
# pin not found 761131.0
# pin not found 761121.0
# pin not found 764069.0
# pin not found 761131.0
# pin not found 761054.0
# pin not found 754034.0
# pin not found 761016.0
# pin not found 761101.0
# pin not found 764069.0
# pin not found 764012.0
# pin not found 750448.0
# pin not found 761132.0
# pin not found 764030.0
# pin not found 751005.0
# pin not found 751005.0
# pin not found 754243.0
# pin not found 761140.0
# pin not found 761143.0
# pin not found 767073.0
# pin not found 712106.0
# pin not found 712606.0
# pin not found 713340.0
# pin not found 722188.0
# pin not found 713172.0
# pin not found 713172.0
# pin not found 713359.0
# pin not found 713165.0
# pin not found 713359.0
# pin not found 722123.0
# pin not found 713378.0
# pin not found 731110.0
# pin not found 713410.0
# pin not found 723231.0
# pin not found 731253.0
# pin not found 713378.0
# pin not found 732158.0
# pin not found 733157.0
# pin not found 742128.0
# pin not found 732213.0
# pin not found 732213.0
# pin not found 700000.0
# pin not found 741150.0
# pin not found 700000.0
# pin not found 741184.0
# pin not found 700000.0
# pin not found 303117.0
# pin not found 301023.0
# pin not found 303107.0
# pin not found 303101.0
# pin not found 325003.0
# pin not found 303708.0
# pin not found 305923.0
# pin not found 303101.0
# pin not found 303329.0
# pin not found 303329.0
# pin not found 303329.0
# pin not found 303341.0
# pin not found 333007.0
# pin not found 332173.0
# pin not found 303320.0
# pin not found 305004.0
# pin not found 303010.0
# pin not found 332727.0
# pin not found 304201.0
# pin not found 302001.0
# pin not found 332745.0
# pin not found 332737.0
# pin not found 303708.0
# pin not found 302001.0
# pin not found 302001.0
# pin not found 302001.0
# pin not found 304201.0
# pin not found 144032.0
# pin not found 142102.0
# pin not found 228001.0
# pin not found 200912.0
# pin not found 209805.0
# pin not found 209815.0
# pin not found 209815.0
# pin not found 313001.0
# pin not found 313001.0
# pin not found 305409.0
# pin not found 313001.0
# pin not found 563127.0
# pin not found 572124.0
# pin not found 562112.0
# pin not found 571511.0
# pin not found 563127.0
# pin not found 562126.0
# pin not found 571501.0
# pin not found 560001.0
# pin not found 563138.0
# pin not found 561212.0
# pin not found 571511.0
# pin not found 560017.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 571511.0
# pin not found 571511.0
# pin not found 560022.0
# pin not found 560001.0
# pin not found 571501.0
# pin not found 571501.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 571501.0
# pin not found 560056.0
# pin not found 572112.0
# pin not found 562119.0
# pin not found 563313.0
# pin not found 571501.0
# pin not found 563103.0
# pin not found 571501.0
# pin not found 560001.0
# pin not found 572101.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 581144.0
# pin not found 581162.0
# pin not found 581125.0
# pin not found 580020.0
# pin not found 581404.0
# pin not found 581133.0
# pin not found 577443.0
# pin not found 581317.0
# pin not found 581134.0
# pin not found 581127.0
# pin not found 581133.0
# pin not found 580020.0
# pin not found 580020.0
# pin not found 580020.0
# pin not found 580020.0
# pin not found 580020.0
# pin not found 580020.0
# pin not found 580020.0
# pin not found 580020.0
# pin not found 575522.0
# pin not found 581214.0
# pin not found 580020.0
# pin not found 580020.0
# pin not found 577443.0
# pin not found 581133.0
# pin not found 582229.0
# pin not found 581155.0
# pin not found 581549.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 501501.0
# pin not found 501201.0
# pin not found 501201.0
# pin not found 501102.0
# pin not found 505349.0
# pin not found 504321.0
# pin not found 505002.0
# pin not found 505417.0
# pin not found 505517.0
# pin not found 505125.0
# pin not found 505515.0
# pin not found 505175.0
# pin not found 505002.0
# pin not found 505002.0
# pin not found 505154.0
# pin not found 505236.0
# pin not found 505086.0
# pin not found 505750.0
# pin not found 505328.0
# pin not found 505173.0
# pin not found 505520.0
# pin not found 505321.0
# pin not found 505183.0
# pin not found 505406.0
# pin not found 573135.0
# pin not found 571419.0
# pin not found 571429.0
# pin not found 571320.0
# pin not found 537116.0
# pin not found 573135.0
# pin not found 571128.0
# pin not found 523404.0
# pin not found 524299.0
# pin not found 517527.0
# pin not found 517292.0
# pin not found 524360.0
# pin not found 524035.0
# pin not found 517292.0
# pin not found 517564.0
# pin not found 503215.0
# pin not found 503214.0
# pin not found 503221.0
# pin not found 548111.0
# pin not found 585285.0
# pin not found 585285.0
# pin not found 584141.0
# pin not found 583284.0
# pin not found 584156.0
# pin not found 584106.0
# pin not found 584156.0
# pin not found 584227.0
# pin not found 584227.0
# pin not found 583106.0
# pin not found 583531.0
# pin not found 585285.0
# pin not found 580235.0
# pin not found 584110.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 543129.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 521191.0
# pin not found 520004.0
# pin not found 534206.0
# pin not found 534419.0
# pin not found 534319.0
# pin not found 534230.0
# pin not found 521107.0
# pin not found 534204.0
# pin not found 534346.0
# pin not found 542185.0
# pin not found 535169.0
# pin not found 532202.0
# pin not found 382724.0
# pin not found 383233.0
# pin not found 383233.0
# pin not found 382727.0
# pin not found 382727.0
# pin not found 382764.0
# pin not found 382727.0
# pin not found 382727.0
# pin not found 385335.0
# pin not found 382009.0
# pin not found 382455.0
# pin not found 383327.0
# pin not found 371392.0
# pin not found 382325.0
# pin not found 382325.0
# pin not found 382764.0
# pin not found 382764.0
# pin not found 382764.0
# pin not found 383000.0
# pin not found 382764.0
# pin not found 382764.0
# pin not found 382857.0
# pin not found 382764.0
# pin not found 382001.0
# pin not found 382001.0
# pin not found 380053.0
# pin not found 382764.0
# pin not found 383200.0
# pin not found 382764.0
# pin not found 382885.0
# pin not found 385370.0
# pin not found 385005.0
# pin not found 383233.0
# pin not found 383015.0
# pin not found 380010.0
# pin not found 383233.0
# pin not found 383233.0
# pin not found 382720.0
# pin not found 380014.0
# pin not found 385002.0
# pin not found 380190.0
# pin not found 393140.0
# pin not found 382001.0
# pin not found 391103.0
# pin not found 391245.0
# pin not found 391246.0
# pin not found 387338.0
# pin not found 388101.0
# pin not found 388003.0
# pin not found 388101.0
# pin not found 391336.0
# pin not found 391237.0
# pin not found 388252.0
# pin not found 391030.0
# pin not found 387023.0
# pin not found 391020.0
# pin not found 387265.0
# pin not found 370610.0
# pin not found 413526.0
# pin not found 431130.0
# pin not found 431130.0
# pin not found 431130.0
# pin not found 413207.0
# pin not found 431130.0
# pin not found 431130.0
# pin not found 414207.0
# pin not found 414207.0
# pin not found 400001.0
# pin not found 412507.0
# pin not found 481127.0
# pin not found 440002.0
# pin not found 441612.0
# pin not found 442911.0
# pin not found 440100.0
# pin not found 442100.0
# pin not found 441211.0
# pin not found 440030.0
# pin not found 440002.0
# pin not found 441111.0
# pin not found 442100.0
# pin not found 440100.0
# pin not found 440100.0
# pin not found 440009.0
# pin not found 413821.0
# pin not found 425205.0
# pin not found 425325.0
# pin not found 425116.0
# pin not found 423304.0
# pin not found 425523.0
# pin not found 425124.0
# pin not found 424008.0
# pin not found 425116.0
# pin not found 425327.0
# pin not found 431716.0
# pin not found 431406.0
# pin not found 431413.0
# pin not found 411012.0
# pin not found 415210.0
# pin not found 415510.0
# pin not found 411046.0
# pin not found 414508.0
# pin not found 413117.0
# pin not found 423708.0
# pin not found 410302.0
# pin not found 360340.0
# pin not found 360350.0
# pin not found 362615.0
# pin not found 361020.0
# pin not found 360610.0
# pin not found 360610.0
# pin not found 360063.0
# pin not found 363622.0
# pin not found 362562.0
# pin not found 361230.0
# pin not found 363625.0
# pin not found 362036.0
# pin not found 361540.0
# pin not found 363035.0
# pin not found 364720.0
# pin not found 367410.0
# pin not found 364720.0
# pin not found 362421.0
# pin not found 364001.0
# pin not found 360080.0
# pin not found 360045.0
# pin not found 361240.0
# pin not found 364421.0
# pin not found 365446.0
# pin not found 508000.0
# pin not found 508216.0
# pin not found 508208.0
# pin not found 528245.0
# pin not found 508265.0
# pin not found 507171.0
# pin not found 517649.0
# pin not found 517321.0
# pin not found 534420.0
# pin not found 534203.0
# pin not found 534203.0
# pin not found 534409.0
# pin not found 534421.0
# pin not found 534102.0
# pin not found 534512.0
# pin not found 534202.0
# pin not found 431909.0
# pin not found 431909.0
# pin not found 431909.0
# pin not found 431024.0
# pin not found 431119.0
# pin not found 431281.0
# pin not found 433702.0
# pin not found 522003.0
# pin not found 522003.0
# pin not found 522003.0
# pin not found 522003.0
# pin not found 522263.0
# pin not found 141207.0
# pin not found 455117.0
# pin not found 453481.0
# pin not found 455002.0
# pin not found 458995.0
# pin not found 458003.0
# pin not found 465338.0
# pin not found 457002.0
# pin not found 452115.0
# pin not found 456666.0
# pin not found 465221.0
# pin not found 457113.0
# pin not found 458007.0
# pin not found 469223.0
# pin not found 485116.0
# pin not found 457002.0
# pin not found 458995.0
# pin not found 450115.0
# pin not found 455113.0
# pin not found 452115.0
# pin not found 452115.0
# pin not found 485118.0
# pin not found 456112.0
# pin not found 465118.0
# pin not found 450113.0
# pin not found 450118.0
# pin not found 465338.0
# pin not found 450111.0
# pin not found 458559.0
# pin not found 458559.0
# pin not found 458559.0
# pin not found 457769.0
# pin not found 450003.0
# pin not found 450052.0
# pin not found 450052.0
# pin not found 458665.0
# pin not found 465338.0
# pin not found 457330.0
# pin not found 450339.0
# pin not found 458995.0
# pin not found 458995.0
# pin not found 457440.0
# pin not found 458995.0
# pin not found 459441.0
# pin not found 451223.0
# pin not found 438441.0
# pin not found 151100.0
# pin not found 733157.0
# pin not found 732212.0
# pin not found 734001.0
# pin not found 734001.0
# pin not found 734001.0
# pin not found 734001.0
# pin not found 121001.0
# pin not found 121001.0
# pin not found 444703.0
# pin not found 444818.0
# pin not found 444608.0
# pin not found 415118.0
# pin not found 413408.0
# pin not found 413408.0
# pin not found 413804.0
# pin not found 400001.0
# pin not found 121001.0
# pin not found 147204.0
# pin not found 147204.0
# pin not found 147204.0
# pin not found 147204.0
# pin not found 147204.0
# pin not found 147204.0
# pin not found 147204.0
# pin not found 147204.0
# pin not found 147204.0
# pin not found 121001.0
# pin not found 121001.0
# pin not found 121001.0
# pin not found 121001.0
# pin not found 585281.0
# pin not found 585278.0
# pin not found 585293.0
# pin not found 588216.0
# pin not found 585285.0
# pin not found 585428.0
# pin not found 585285.0
# pin not found 585285.0
# pin not found 585439.0
# pin not found 586169.0
# pin not found 585431.0
# pin not found 585428.0
# pin not found 585427.0
# pin not found 560001.0
# pin not found 585285.0
# pin not found 560001.0
# pin not found 585428.0
# pin not found 560001.0
# pin not found 560001.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 461114.0
# pin not found 460444.0
# pin not found 460662.0
# pin not found 460662.0
# pin not found 460662.0
# pin not found 487116.0
# pin not found 480361.0
# pin not found 480339.0
# pin not found 460662.0
# pin not found 487223.0
# pin not found 461991.0
# pin not found 430001.0
# pin not found 324003.0
# pin not found 324003.0
# pin not found 324001.0
# pin not found 342005.0
# pin not found 313001.0
# pin not found 313001.0
# pin not found 313001.0
# pin not found 416121.0
# pin not found 803205.0
# pin not found 803205.0
# pin not found 804422.0
# pin not found 496553.0
# pin not found 509021.0
# pin not found 505747.0
# pin not found 503312.0
# 9875

# %%
# solve where pin is available and city is not and that pin has only one city
def replace_city_with_pin(x):
    if pd.isnull(x[0]):
        try:
            if (not np.isnan(x[1]))  and len(pin_city[x[1]]) == 1: 
                return list(pin_city[x[1]])[0]
            else:
                return x[0]
        except:
            return x[0]
    return x[0]
df['City'] = df[['City', 'ZiPCODE']].apply(lambda x: replace_city_with_pin(x), axis=1)

# %%
df.City.isnull().sum()
# Out:
# 1381

# %%
# solve where area is available and city is not and area has only one city
def replace_city_with_area(x):
    if pd.isnull(x[0]):
        try:
            if (not pd.isnull(x[1])) and len(area_city[x[1]]) == 1:
                return list(area_city[x[1]])[0]
            elif x[1] in area_city: return x[1]
            else: return x[0]
        except:
            return x[0]
    return x[0]
df['City'] = df[['City', 'Area']].apply(lambda x: replace_city_with_area(x), axis=1)

# %%
df.City.isnull().sum()
# Out:
# 154

# %% [markdown]
# # fix Area

# %%
df.Area.isnull().sum()
# Out:
# 11653

# %%
# solve where city is available and area is not and city has only one area
def replace_area_with_city(x):
    if pd.isnull(x[0]):
        try:
            if (not pd.isnull(x[1])) and len(city_area[x[1]]) == 1:
                return list(city_area[x[1]])[0]
#             elif x[1] in area_city: return x[1]
            else: return x[0]
        except:
            return x[0]
    return x[0]
df['Area'] = df[['Area', 'City']].apply(lambda x: replace_area_with_city(x), axis=1)

# %%
df.Area.isnull().sum()
# Out:
# 7545

# %%
# solve where pin is available and area is not and that pin has only one area
def replace_area_with_pin(x):
    if pd.isnull(x[0]):
        try:
            if (not np.isnan(x[1]))  and len(pin_area[x[1]]) == 1: 
                return list(pin_area[x[1]])[0]
            else:
                return x[0]
        except:
            return x[0]
    return x[0]
df['Area'] = df[['Area', 'ZiPCODE']].apply(lambda x: replace_area_with_pin(x), axis=1)

# %%
df.Area.isnull().sum()
# Out:
# 4242

# %%
# creating area => city, pin => area, pin => city
test_pin_area = {}
test_city_area = {}
for area, pin, city in zip(tdf.Area.values, tdf.ZiPCODE.values, tdf.City.values):
    x = np.isnan(pin)
    y = pd.isnull(area)
    z = pd.isnull(city)
    
    if not (x or y): 
        if pin not in test_pin_area: test_pin_area[pin] = set()
        test_pin_area[pin].add(area)
#     if not (x or z):
#         if pin not in pin_city: pin_city[pin] = set()
#         pin_city[pin].add(city)
    
    if not (y or z):
        if city not in test_city_area: test_city_area[city] = set()
        test_city_area[city].add(area)

# %%
print(tdf.Area.isnull().sum())
def test_replace_area_with_city(x):
    if pd.isnull(x[0]):
        try:
            if (not pd.isnull(x[1])) and len(test_city_area[x[1]]) == 1:
                return list(test_city_area[x[1]])[0]
#             elif x[1] in area_city: return x[1]
            else: return x[0]
        except:
            return x[0]
    return x[0]
tdf['Area'] = tdf[['Area', 'City']].apply(lambda x: test_replace_area_with_city(x), axis=1)
print(tdf.Area.isnull().sum())

def test_replace_area_with_pin(x):
    if pd.isnull(x[0]):
        try:
            if (not np.isnan(x[1]))  and len(test_pin_area[x[1]]) == 1: 
                return list(test_pin_area[x[1]])[0]
            else:
                return x[0]
        except:
            return x[0]
    return x[0]

tdf['Area'] = tdf[['Area', 'ZiPCODE']].apply(lambda x: test_replace_area_with_pin(x), axis=1)
print(tdf.Area.isnull().sum())
# Out:
# 546
# 395
# 346
