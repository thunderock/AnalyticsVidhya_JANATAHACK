# 2626  id_30      0  2017-02-15  83.322  84.4489  83.3619  84.4636        0
# 2657  id_30      0  2017-02-15  83.322  84.4489  83.3619  84.4636        0
#
#       unpredictability_score  train               id
# 480                        7      1  (0, 2017-02-15)
# 511                        7      1  (0, 2017-02-16)
# 542                        7      1  (0, 2017-02-17)
# 573                        7      1  (0, 2017-02-21)
# 604                        7      1  (0, 2017-02-22)
# 635                        7      1  (0, 2017-02-23)
# 666                        7      1  (0, 2017-02-24)
# 697                        7      1  (0, 2017-02-27)
# 1944                       7      1  (0, 2017-02-28)
# 1975                       7      1  (0, 2017-03-01)
# 2006                       7      1  (0, 2017-03-02)
# 2037                       7      1  (0, 2017-03-03)
# 2068                       7      1  (0, 2017-03-06)
# 2099                       7      1  (0, 2017-03-07)
# 2130                       7      1  (0, 2017-03-08)
# 2161                       7      1  (0, 2017-03-09)
# 2192                       7      1  (0, 2017-03-10)
# 2223                       7      1  (0, 2017-03-13)
# 2254                       7      1  (0, 2017-03-14)
# 2285                       7      1  (0, 2017-03-15)
# 2316                       7      1  (0, 2017-03-16)
# 2347                       7      1  (0, 2017-03-17)
# 2378                       7      1  (0, 2017-03-20)
# 2409                       7      1  (0, 2017-03-21)
# 2440                       7      1  (0, 2017-03-22)
# 2471                       7      1  (0, 2017-03-23)
# 2502                       7      1  (0, 2017-03-24)
# 2533                       7      1  (0, 2017-03-27)
# 2564                       7      1  (0, 2017-03-28)
# 2595                       7      1  (0, 2017-03-29)
# 2626                       7      1  (0, 2017-03-30)
# 2657                       7      1  (0, 2017-03-31)

# %%
df_rolled[df_rolled['train'] ==0].head()
# Out:
#            ID  stock        Date  Open  High  Low  Close  holiday  \
# 22336  id_713      0  2019-11-01   NaN   NaN  NaN    NaN        0
# 22367  id_713      0  2019-11-01   NaN   NaN  NaN    NaN        0
# 22368  id_714      0  2019-11-04   NaN   NaN  NaN    NaN        0
# 22398  id_713      0  2019-11-01   NaN   NaN  NaN    NaN        0
# 22399  id_714      0  2019-11-04   NaN   NaN  NaN    NaN        0
#
#        unpredictability_score  train               id
# 22336                       7      0  (0, 2019-11-01)
# 22367                       7      0  (0, 2019-11-04)
# 22368                       7      0  (0, 2019-11-04)
# 22398                       7      0  (0, 2019-11-05)
# 22399                       7      0  (0, 2019-11-05)

# %%
len(df), df_rolled.id.nunique()

# %%
df_rolled.groupby("id").size().agg([np.min, np.max])

# %%
X = extract_features(df_rolled.drop(columns=["Open", "High", "Low", "Close", "ID", "train"], axis=1), 
                     column_id="stock", column_sort="Date", 
                     show_warnings=False, n_jobs=7, impute_function=impute)

# %%
X

# %%
X.shape

# %%
X.columns

# %%
X.index

# %%
X = X.set_index(X.index.map(lambda x: x[1]), drop=True)
X.index.name = "last_date"
X

# %%
y = df.set_index("Date").sort_index().Open

# %%
y

# %%
y = y[y.index.isin(X.index)]
X = X[X.index.isin(y.index)]

# %%
X.shape, y.shape

# %%
X_train, X_test = X[:570], X[570:]
y_train, y_test = y[:570], y[570:]
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
X_train

# %%
X_test

# %%
for col in X_train.columns:
    if X_train[col].isnull().sum() != 0:
        print(col)

# %%
X_train_selected = select_features(X_train, y_train)

# %%
X_train_selected

# %%
ada = LinearRegression()

ada.fit(X_train_selected, y_train)

# %%
X_test_selected = X_test[X_train_selected.columns]

y_pred = pd.Series(ada.predict(X_test_selected), index=X_test_selected.index)

# %%
plt.figure(figsize=(15, 6))

y.plot(ax=plt.gca())
y_pred.plot(ax=plt.gca(), legend=None, marker=".")

# %%
X_test_selected

# %%
y_pred

# %%
y_test

# %%
print(mean_squared_error(y_test.tolist(), y_pred.tolist(), squared=False))
